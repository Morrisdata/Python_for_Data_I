# %% [markdown]
# ### Merge
# for more information check out this helpful link http://www.datacarpentry.org/python-ecology-lesson/04-merging-data/
#
# * Store products information in 'prd' variable
# * Store Sales information in 'sls' variable
# * Inner, outer, Left, Right

# %%
prd = pd.read_sql_query('select * from products', conn)
sls = pd.read_sql_query('select * from sales limit 1000', conn)

# %%
# Only include observations found in both prd and sls: Inner Join
pd.merge(prd, sls, left_on='item_no',right_on='item')
# Out:
#        item_no                     category_name_x  \
# 0       904616  MISC. AMERICAN CORDIALS & LIQUEURS
# 1       904617  MISC. IMPORTED CORDIALS & LIQUEURS
# 2       904618                      PEACH BRANDIES
# 3       904619                     SCOTCH WHISKIES
# 4       904620                      FLAVORED VODKA
# 5       904621           STRAIGHT BOURBON WHISKIES
# 6       904622  MISC. AMERICAN CORDIALS & LIQUEURS
# 7       904623              MISCELLANEOUS BRANDIES
# 8       904624                      IMPORTED VODKA
# 9       904625                        FLAVORED RUM
# 10      904626                  SINGLE MALT SCOTCH
# 11      904627                        FLAVORED RUM
# 12      904628                     SCOTCH WHISKIES
# 13      904629         DISTILLED SPIRITS SPECIALTY
# 14      904630           STRAIGHT BOURBON WHISKIES
# 15      904631                   IMPORTED DRY GINS
# 16      904632  MISC. AMERICAN CORDIALS & LIQUEURS
# 17      904633                      FLAVORED VODKA
# 18      904634                  AMERICAN COCKTAILS
# 19      904635                      IMPORTED VODKA
# 20      904636         DISTILLED SPIRITS SPECIALTY
# 21      904637                      IMPORTED VODKA
# 22      904638  MISC. AMERICAN CORDIALS & LIQUEURS
# 23      904639             IMPORTED GRAPE BRANDIES
# 24      904640  MISC. AMERICAN CORDIALS & LIQUEURS
# 25      904641                  SINGLE MALT SCOTCH
# 26      904642  MISC. IMPORTED CORDIALS & LIQUEURS
# 27      904643    PUERTO RICO & VIRGIN ISLANDS RUM
# 28      904644                 PEPPERMINT SCHNAPPS
# 29      904645                      IMPORTED VODKA
# ...        ...                                 ...
# 10402   904585                         JAMAICA RUM
# 10403   904586                   CANADIAN WHISKIES
# 10404   904587                             TEQUILA
# 10405   904588                             TEQUILA
# 10406   904589                        FLAVORED RUM
# 10407   904590                      FLAVORED VODKA
# 10408   904591                        FLAVORED RUM
# 10409   904592                      FLAVORED VODKA
# 10410   904593  MISC. IMPORTED CORDIALS & LIQUEURS
# 10411   904594                      IRISH WHISKIES
# 10412   904595    PUERTO RICO & VIRGIN ISLANDS RUM
# 10413   904596                         JAMAICA RUM
# 10414   904597                 BLACKBERRY BRANDIES
# 10415   904598                      FLAVORED VODKA
# 10416   904599                             TEQUILA
# 10417   904600                             TEQUILA
# 10418   904601                      FLAVORED VODKA
# 10419   904602    PUERTO RICO & VIRGIN ISLANDS RUM
# 10420   904603                      IMPORTED VODKA
# 10421   904604                      IMPORTED VODKA
# 10422   904605                      IMPORTED VODKA
# 10423   904607                     SCOTCH WHISKIES
# 10424   904608           STRAIGHT BOURBON WHISKIES
# 10425   904609                     SCOTCH WHISKIES
# 10426   904610                      FLAVORED VODKA
# 10427   904611                      CREAM LIQUEURS
# 10428   904612                  SINGLE MALT SCOTCH
# 10429   904613         DISTILLED SPIRITS SPECIALTY
# 10430   904614  MISC. AMERICAN CORDIALS & LIQUEURS
# 10431   904615                      FLAVORED VODKA
#
#                                    item_description  vendor_x  \
# 0                            Travis Hasse Apple Pie       305
# 1                                D'aristi Xtabentun       391
# 2                         Hiram Walker Peach Brandy       370
# 3                                  Oak Cross Whisky       305
# 4                              Uv Red(cherry) Vodka       380
# 5                 Heaven Hill Old Style White Label       259
# 6                               Hyde Herbal Liqueur       194
# 7                      Dupont Calvados Fine Reserve       403
# 8                             Sobieski Cytron Vodka       267
# 9              Captain Morgan Parrot Bay Strawberry       260
# 10                                       Arran 10yr        10
# 11                           Malibu Tropical Banana       370
# 12                               Ballantines Finest       370
# 13                      Catdaddy Carolina Moonshine       384
# 14                           Early Times Mint Julep        85
# 15                               Tanqueray Gin Mini       260
# 16                 Hiram Walker Creme De Strawberry       370
# 17                       Seagram's Wild Grape Vodka       255
# 18         Seagram's Ruby Red Grapfruit Gin & Juice       370
# 19                  Grey Goose La Poire Vodka(pear)        35
# 20                               Virginia Moonshine        68
# 21                            Sobieski Cytron Vodka       267
# 22                              Dekuyper Lemon Drop        65
# 23                         Tosolini Cividina Grappa       338
# 24                         Dekuyper Alabama Slammer        65
# 25                         Glenrothes Triple Double       461
# 26                                    Nassau Royale        35
# 27                           Brugal Extra Veijo Rum       305
# 28                                          Ice 101       298
# 29                                 Ketel One Citoen       260
# ...                                             ...       ...
# 10402                    Appleton Special White Rum       461
# 10403                     Forty Creek Barrel Select       461
# 10404                                Cabrito Blanco       256
# 10405                     El Jimador Silver Tequila        85
# 10406                    Admiral Nelson Vanilla Rum       259
# 10407                                   Bakon Vodka       394
# 10408                     Bacardi Dragon Berry Mini        35
# 10409                                Uv Grape Vodka       380
# 10410                             Tequila Rose Java       300
# 10411                     Powers 12yr Irish Whiskey       370
# 10412                   Mccormick Silver Do Not Use       300
# 10413                       Appleton Estate Reserve       461
# 10414                        Bols Blackberry Brandy       305
# 10415                    Uv Green Apple Vodka Glass       380
# 10416                    Corralejo Reposado Teuqila       255
# 10417                               Don Julio Anejo       260
# 10418                          Uv Red(cherry) Vodka       380
# 10419                               Velvet Falernum       305
# 10420                    Alchemia Wild Cherry Vodka       305
# 10421                         Alchemia Ginger Vodka       305
# 10422                                Sobieski Vodka       267
# 10423                         Black Bottle Original       270
# 10424                Wild Turkey 8 Yr Ky St Bourbon       461
# 10425                          Longmorn 16yr Scotch       370
# 10426                  Smirnoff Twist Of Watermelon       260
# 10427                            1921 Tequila Cream       109
# 10428                              Glendronach 15yo       391
# 10429  Junior Johnson's Midnight Moon Lemonade(dno)       384
# 10430                          Jekyll Berry Liqueur       194
# 10431                 Smirnoff Twist Of Citrus Mini       260
#
#                               vendor_name  bottle_size  pack_x  inner_pack  \
# 0                                 Mhw Ltd          750      12           1
# 1      Anchor Distilling (preiss Imports)          750      12           1
# 2        Pernod Ricard Usa/austin Nichols         1000      12           1
# 3                                 Mhw Ltd          750       6           1
# 4               Phillips Beverage Company          200      24           1
# 5           Heaven Hill Distilleries Inc.          750      12           1
# 6                    Fire Tail Brands Llc          750      12           1
# 7                Robert Kacher Selections          750      12           1
# 8                    Imperial Brands Inc.          750      12           1
# 9                         Diageo Americas          750      12           1
# 10                  A Hardy / U.s.a. Ltd.          750       6           1
# 11       Pernod Ricard Usa/austin Nichols         1000      12           1
# 12       Pernod Ricard Usa/austin Nichols         1750       6           1
# 13                    Piedmont Distillers          750       6           1
# 14               Brown-forman Corporation         1000      12           1
# 15                        Diageo Americas          502      12           1
# 16       Pernod Ricard Usa/austin Nichols         1000      12           1
# 17                    Wilson Daniels Ltd.          200      24           1
# 18       Pernod Ricard Usa/austin Nichols          375      12           1
# 19                    Bacardi U.s.a. Inc.          750       6           1
# 20               Belmont Farms Of Va. Inc          750      12           1
# 21                   Imperial Brands Inc.         1000      12           1
# 22                        Jim Beam Brands          750      12           1
# 23                       Niche Import Co.         1000       6           1
# 24                        Jim Beam Brands          750      12           1
# 25                          Campari(skyy)          301      12           1
# 26                    Bacardi U.s.a. Inc.         1000      12           1
# 27                                Mhw Ltd          750      12           1
# 28           White Rock Distilleries Inc.          375      24           1
# 29                        Diageo Americas         1000      12           1
# ...                                   ...          ...     ...         ...
# 10402                       Campari(skyy)          750      12           1
# 10403                       Campari(skyy)         1000      12           1
# 10404                       Haas Brothers         1000      12           1
# 10405            Brown-forman Corporation         1750       6           1
# 10406       Heaven Hill Distilleries Inc.         1750       6           1
# 10407                  Black Rock Spirits          750      12           1
# 10408                 Bacardi U.s.a. Inc.          502     120           1
# 10409           Phillips Beverage Company          375      12           1
# 10410        Mccormick Distilling Company          750      12           1
# 10411    Pernod Ricard Usa/austin Nichols          750       6           1
# 10412        Mccormick Distilling Company         1000      12           1
# 10413                       Campari(skyy)          750       6           1
# 10414                             Mhw Ltd         1000      12           1
# 10415           Phillips Beverage Company          200      24           1
# 10416                 Wilson Daniels Ltd.         1750       6           1
# 10417                     Diageo Americas          375      12           1
# 10418           Phillips Beverage Company          375      12           1
# 10419                             Mhw Ltd          750      12           1
# 10420                             Mhw Ltd          750       6           1
# 10421                             Mhw Ltd          750       6           1
# 10422                Imperial Brands Inc.         1000      12           1
# 10423     International Beverage Co. Inc.          750       6           1
# 10424                       Campari(skyy)         1750       6           1
# 10425    Pernod Ricard Usa/austin Nichols          750       3           1
# 10426                     Diageo Americas          502      12          10
# 10427                       Casa 1921 Llc          750       6           1
# 10428  Anchor Distilling (preiss Imports)          750       1           1
# 10429                 Piedmont Distillers          750       6           1
# 10430                Fire Tail Brands Llc          750      12           1
# 10431                     Diageo Americas          502      12          10
#
#         age proof  ...  vendor_no vendor_y item description  pack_y  \
# 0      None    40  ...        NaN      NaN  NaN         NaN     NaN
# 1      None    60  ...        NaN      NaN  NaN         NaN     NaN
# 2      None    60  ...        NaN      NaN  NaN         NaN     NaN
# 3      None    86  ...        NaN      NaN  NaN         NaN     NaN
# 4      None    60  ...        NaN      NaN  NaN         NaN     NaN
# 5      None    80  ...        NaN      NaN  NaN         NaN     NaN
# 6      None    80  ...        NaN      NaN  NaN         NaN     NaN
# 7      None    80  ...        NaN      NaN  NaN         NaN     NaN
# 8      None    80  ...        NaN      NaN  NaN         NaN     NaN
# 9      None    42  ...        NaN      NaN  NaN         NaN     NaN
# 10     None    92  ...        NaN      NaN  NaN         NaN     NaN
# 11     None    42  ...        NaN      NaN  NaN         NaN     NaN
# 12     None    80  ...        NaN      NaN  NaN         NaN     NaN
# 13     None    80  ...        NaN      NaN  NaN         NaN     NaN
# 14     None    60  ...        NaN      NaN  NaN         NaN     NaN
# 15     None    94  ...        NaN      NaN  NaN         NaN     NaN
# 16     None    30  ...        NaN      NaN  NaN         NaN     NaN
# 17     None    70  ...        NaN      NaN  NaN         NaN     NaN
# 18     None    35  ...        NaN      NaN  NaN         NaN     NaN
# 19     None    80  ...        NaN      NaN  NaN         NaN     NaN
# 20     None   100  ...        NaN      NaN  NaN         NaN     NaN
# 21     None    70  ...        NaN      NaN  NaN         NaN     NaN
# 22     None    40  ...        NaN      NaN  NaN         NaN     NaN
# 23     None    80  ...        NaN      NaN  NaN         NaN     NaN
# 24     None    40  ...        NaN      NaN  NaN         NaN     NaN
# 25     None    86  ...        NaN      NaN  NaN         NaN     NaN
# 26     None    68  ...        NaN      NaN  NaN         NaN     NaN
# 27     None    80  ...        NaN      NaN  NaN         NaN     NaN
# 28     None   101  ...        NaN      NaN  NaN         NaN     NaN
# 29     None    80  ...        NaN      NaN  NaN         NaN     NaN
# ...     ...   ...  ...        ...      ...  ...         ...     ...
# 10402  None    80  ...        NaN      NaN  NaN         NaN     NaN
# 10403  None    80  ...        NaN      NaN  NaN         NaN     NaN
# 10404  None    80  ...        NaN      NaN  NaN         NaN     NaN
# 10405  None    80  ...        NaN      NaN  NaN         NaN     NaN
# 10406  None    70  ...        NaN      NaN  NaN         NaN     NaN
# 10407  None    80  ...        NaN      NaN  NaN         NaN     NaN
# 10408  None    70  ...        NaN      NaN  NaN         NaN     NaN
# 10409  None    60  ...        NaN      NaN  NaN         NaN     NaN
# 10410  None    30  ...        NaN      NaN  NaN         NaN     NaN
# 10411  None    80  ...        NaN      NaN  NaN         NaN     NaN
# 10412  None    80  ...        NaN      NaN  NaN         NaN     NaN
# 10413  None    80  ...        NaN      NaN  NaN         NaN     NaN
# 10414  None    70  ...        NaN      NaN  NaN         NaN     NaN
# 10415  None    60  ...        NaN      NaN  NaN         NaN     NaN
# 10416  None    80  ...        NaN      NaN  NaN         NaN     NaN
# 10417  None    80  ...        NaN      NaN  NaN         NaN     NaN
# 10418  None    60  ...        NaN      NaN  NaN         NaN     NaN
# 10419  None    22  ...        NaN      NaN  NaN         NaN     NaN
# 10420  None    80  ...        NaN      NaN  NaN         NaN     NaN
# 10421  None    80  ...        NaN      NaN  NaN         NaN     NaN
# 10422  None    80  ...        NaN      NaN  NaN         NaN     NaN
# 10423  None    80  ...        NaN      NaN  NaN         NaN     NaN
# 10424  None   101  ...        NaN      NaN  NaN         NaN     NaN
# 10425  None    96  ...        NaN      NaN  NaN         NaN     NaN
# 10426  None    70  ...        NaN      NaN  NaN         NaN     NaN
# 10427  None    30  ...        NaN      NaN  NaN         NaN     NaN
# 10428  None    92  ...        NaN      NaN  NaN         NaN     NaN
# 10429  None    80  ...        NaN      NaN  NaN         NaN     NaN
# 10430  None    60  ...        NaN      NaN  NaN         NaN     NaN
# 10431  None    70  ...        NaN      NaN  NaN         NaN     NaN
#
#        liter_size state_btl_cost btl_price  bottle_qty total
# 0             NaN            NaN       NaN         NaN   NaN
# 1             NaN            NaN       NaN         NaN   NaN
# 2             NaN            NaN       NaN         NaN   NaN
# 3             NaN            NaN       NaN         NaN   NaN
# 4             NaN            NaN       NaN         NaN   NaN
# 5             NaN            NaN       NaN         NaN   NaN
# 6             NaN            NaN       NaN         NaN   NaN
# 7             NaN            NaN       NaN         NaN   NaN
# 8             NaN            NaN       NaN         NaN   NaN
# 9             NaN            NaN       NaN         NaN   NaN
# 10            NaN            NaN       NaN         NaN   NaN
# 11            NaN            NaN       NaN         NaN   NaN
# 12            NaN            NaN       NaN         NaN   NaN
# 13            NaN            NaN       NaN         NaN   NaN
# 14            NaN            NaN       NaN         NaN   NaN
# 15            NaN            NaN       NaN         NaN   NaN
# 16            NaN            NaN       NaN         NaN   NaN
# 17            NaN            NaN       NaN         NaN   NaN
# 18            NaN            NaN       NaN         NaN   NaN
# 19            NaN            NaN       NaN         NaN   NaN
# 20            NaN            NaN       NaN         NaN   NaN
# 21            NaN            NaN       NaN         NaN   NaN
# 22            NaN            NaN       NaN         NaN   NaN
# 23            NaN            NaN       NaN         NaN   NaN
# 24            NaN            NaN       NaN         NaN   NaN
# 25            NaN            NaN       NaN         NaN   NaN
# 26            NaN            NaN       NaN         NaN   NaN
# 27            NaN            NaN       NaN         NaN   NaN
# 28            NaN            NaN       NaN         NaN   NaN
# 29            NaN            NaN       NaN         NaN   NaN
# ...           ...            ...       ...         ...   ...
# 10402         NaN            NaN       NaN         NaN   NaN
# 10403         NaN            NaN       NaN         NaN   NaN
# 10404         NaN            NaN       NaN         NaN   NaN
# 10405         NaN            NaN       NaN         NaN   NaN
# 10406         NaN            NaN       NaN         NaN   NaN
# 10407         NaN            NaN       NaN         NaN   NaN
# 10408         NaN            NaN       NaN         NaN   NaN
# 10409         NaN            NaN       NaN         NaN   NaN
# 10410         NaN            NaN       NaN         NaN   NaN
# 10411         NaN            NaN       NaN         NaN   NaN
# 10412         NaN            NaN       NaN         NaN   NaN
# 10413         NaN            NaN       NaN         NaN   NaN
# 10414         NaN            NaN       NaN         NaN   NaN
# 10415         NaN            NaN       NaN         NaN   NaN
# 10416         NaN            NaN       NaN         NaN   NaN
# 10417         NaN            NaN       NaN         NaN   NaN
# 10418         NaN            NaN       NaN         NaN   NaN
# 10419         NaN            NaN       NaN         NaN   NaN
# 10420         NaN            NaN       NaN         NaN   NaN
# 10421         NaN            NaN       NaN         NaN   NaN
# 10422         NaN            NaN       NaN         NaN   NaN
# 10423         NaN            NaN       NaN         NaN   NaN
# 10424         NaN            NaN       NaN         NaN   NaN
# 10425         NaN            NaN       NaN         NaN   NaN
# 10426         NaN            NaN       NaN         NaN   NaN
# 10427         NaN            NaN       NaN         NaN   NaN
# 10428         NaN            NaN       NaN         NaN   NaN
# 10429         NaN            NaN       NaN         NaN   NaN
# 10430         NaN            NaN       NaN         NaN   NaN
# 10431         NaN            NaN       NaN         NaN   NaN
#
# [10432 rows x 33 columns]

# %%
# Only include observations from left side regardless of a match on the right side
lf=pd.merge(prd, sls, left_on='item_no',right_on='item', how='right')

# %%
lf[ pd.isnull(lf.item) ]
# Out:
# Empty DataFrame
# Columns: [item_no, category_name_x, item_description, vendor_x, vendor_name, bottle_size, pack_x, inner_pack, age, proof, list_date, upc, scc, bottle_price, shelf_price, case_cost, date, convenience_store, store, county_number, county, category, category_name_y, vendor_no, vendor_y, item, description, pack_y, liter_size, state_btl_cost, btl_price, bottle_qty, total]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# As with most things covered in this crash course this is just the tip of the iceberg but it should
# get you up and running with data.

# %%
#### Intro to visualiazation from Pandas
* Bar plot
* Stacked Bar plots
* Box plot
* Histogram
* Add title and labels
* Scatter plot
* Add Transparency
* Vary point by Color

# %%
import matplotlib.pyplot as plt

# display plots in the notebook
# %matplotlib inline

# increase default figure and font sizes for easier viewing
plt.rcParams# increase default figure and font sizes for easier viewing
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# count the number of items in each category
prd.category_name.value_counts()
# Out:
# DECANTERS & SPECIALTY PACKAGES         True
# IMPORTED ALE                           True
# FLAVORED VODKA                         True
# MISC. IMPORTED CORDIALS & LIQUEURS     True
# TEQUILA                                True
# IMPORTED VODKA                        False
# SCOTCH WHISKIES                       False
# AMERICAN COCKTAILS                    False
# SINGLE MALT SCOTCH                    False
# STRAIGHT BOURBON WHISKIES             False
# FLAVORED RUM                          False
# IMPORTED VODKA - MISC                 False
# CANADIAN WHISKIES                     False
# MISC. AMERICAN CORDIALS & LIQUEURS    False
# IMPORTED GRAPE BRANDIES               False
# 80 PROOF VODKA                        False
# PUERTO RICO & VIRGIN ISLANDS RUM      False
# CREAM LIQUEURS                        False
# BLENDED WHISKIES                      False
# AMERICAN DRY GINS                     False
# IRISH WHISKIES                        False
# MISCELLANEOUS SCHNAPPS                False
# DISTILLED SPIRITS SPECIALTY           False
# MISCELLANEOUS BRANDIES                False
# IMPORTED DRY GINS                     False
# AMERICAN GRAPE BRANDIES               False
# HIGH PROOF BEER                       False
# WHISKEY LIQUEUR                       False
# SPICED RUM                            False
# PEPPERMINT SCHNAPPS                   False
#                                       ...
# AMERICAN AMARETTO                     False
# TRIPLE SEC                            False
# JAMAICA RUM                           False
# SINGLE BARREL BOURBON WHISKIES        False
# APRICOT BRANDIES                      False
# ROOT BEER SCHNAPPS                    False
# TROPICAL FRUIT SCHNAPPS               False
# FLAVORED GIN                          False
# BUTTERSCOTCH SCHNAPPS                 False
# RASPBERRY SCHNAPPS                    False
# AMERICAN SLOE GINS                    False
# LOW PROOF VODKA                       False
# WATERMELON SCHNAPPS                   False
# AMERICAN ALCOHOL                      False
# CHERRY BRANDIES                       False
# 100 PROOF VODKA                       False
# PEACH BRANDIES                        False
# WHITE CREME DE CACAO                  False
# GREEN CREME DE MENTHE                 False
# DARK CREME DE CACAO                   False
# WHITE CREME DE MENTHE                 False
# BOTTLED IN BOND BOURBON               False
# STRAWBERRY SCHNAPPS                   False
# GRAPE SCHNAPPS                        False
# CREME DE ALMOND                       False
# OTHER PROOF VODKA                     False
# IMPORTED AMARETTO                     False
# SPEARMINT SCHNAPPS                    False
# ANISETTE                              False
# ROCK & RYE                            False
# Name: category_name, dtype: bool

# %%
# compare with bar plot
prd.category_name.value_counts().plot(kind='bar')

# %%
# calculate the mean alcohol amounts for each continent
drinks.groupby('continent').mean()


# side-by-side bar plots
drinks.groupby('continent').mean().plot(kind='bar')


# drop the liters column
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar')


# stacked bar plots
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar', stacked=True)

# %% [markdown]
# # Next Steps
#
# **Recommended Resources**
#
# Name | Description
# --- | ---
# [Official Pandas Tutorials](http://pandas.pydata.org/pandas-docs/stable/tutorials.html) | Wes & Company's selection of tutorials and lectures
# [Julia Evans Pandas Cookbook](https://github.com/jvns/pandas-cookbook) | Great resource with examples from weather, bikes and 311 calls
# [Learn Pandas Tutorials](https://bitbucket.org/hrojas/learn-pandas) | A great series of Pandas tutorials from Dave Rojas
# [Research Computing Python Data PYNBs](https://github.com/ResearchComputing/Meetup-Fall-2013/tree/master/python) | A super awesome set of python notebooks from a meetup-based course exclusively devoted to pandas
